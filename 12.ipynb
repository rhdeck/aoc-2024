# %%
with open('12.txt', 'r') as f:
    input = f.read()
    lines = input.strip().split('\n')
    grid = [[c for c in line] for line in lines] #[list(line) for line in lines]

print(grid)
# Out:
# [['G', 'G', 'G', 'G', 'G', 'D', 'D', 'D', 'D', 'S', 'S', 'S', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'U', 'F', 'F', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Y', 'Y', 'K', 'K', 'K', 'K', 'X', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'N', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'V', 'Y', 'Y', 'E', 'E', 'Z', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'B', 'N', 'S', 'S', 'N', 'N', 'N', 'W', 'U', 'U', 'U', 'U', 'U', 'U', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H'], ['G', 'G', 'D', 'D', 'D', 'D', 'D', 'D', 'D', 'S', 'S', 'S', 'S', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'E', 'F', 'F', 'F', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'Y', 'Y', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'K', 'N', 'N', 'N',
# ...

# %%
def print_grid(grid, target):
    for row in grid:
        for cell in row:
            if target == None or cell == target:
                print(cell, end='')
            else:
                print('.', end='')
        print('')
        # print(''.join(row))
print_grid(grid, 'N')
# Out:
# .........................................................N........................NNNNNNNNNN.N..NNN.........................................
# ........................................................NNN......................NNNNNNNNNNNNN.NNN..........................................
# .........................................................NN......................N.NNNNNNNNNNNNNNN..........................................
# ........................................................NNN.........................NNNNNNNNNNNNN...........................................
# ........................................................NNN..........................NNNNNNNNNNN................................N...........
# ...............................N......................NNNN..............................NNNNNNNN................................N...........
# ...

# %%
regions = []
region_index = {}
# print(grid)
for i in range(len(grid)):
    # print("row length", len(grid[i]), i)
    for j in range(len(grid[0])):
        value = grid[i][j]
        s = str((i,j))
        edgecounter =0
        # print(s)
        if i >0:
            if grid[i-1][j] == value :
                # print("Matching above on ", value)  
                region = region_index[str((i-1,j))]
                region_index[s] = region
                edgecounter += 1
        if j > 0:
            if grid[i][j-1] == value:
                if region != None:
                    # we have to join the regions
                    oldRegion = region_index[str((i,j-1))]
                    if(oldRegion != region):
                        # print(oldRegion)
                        regions.remove(oldRegion)
                        for key in oldRegion.keys():
                            region[key] = oldRegion[key]
                            region_index[key] = region
                else:
                    # print("Matching left on ", value)
                    region = region_index[str((i,j-1))]
                region_index[s] = region
                edgecounter += 1

        if edgecounter == 0:
            region = {}
            regions.append(region)
            region_index[s] = region
        if i < len(grid)-1:
            if grid[i+1][j] == value:
                edgecounter += 1
        if j < len(grid[i])-1:
            if grid[i][j+1] == value:
                edgecounter += 1
        if edgecounter < 4 :
            region[s] = {"edges": 4- edgecounter}
        else:
            region[s] = {"edges": 0} 
        region[s]["coordinates"] = (i,j)
        # check to see if this is an edge by looking at the
        # check to see if this is an edge by looking at the 
# for i in regions:
#     print(i)
print(len(regions))
print(len(region_index.keys()))
# Out:
# 620
# 19600

# %% [markdown]
# # Parts 1 and 2
#
# Done with infill and some help from Windsurf composer to fix my syntax in dealing with boolean tests in python (e.g. ! is not a thing)

# %%
scores = []
scores2 = []
for region in regions:
    perimeter = 0
    area = 0
    corners = 0
    for key, value in region.items():
        #count corners - how many diagonals are missing?
        perimeter = perimeter +value["edges"]
        area = area + 1
        # what is a corner? A corner is a cell that has 
          # Part 2 - count corners
        top = region_index.get(str((value["coordinates"][0]-1, value["coordinates"][1]))) == region
        bottom = region_index.get(str((value["coordinates"][0]+1, value["coordinates"][1]))) == region
        left = region_index.get(str((value["coordinates"][0], value["coordinates"][1]-1))) == region
        right = region_index.get(str((value["coordinates"][0], value["coordinates"][1]+1))) == region
        top_left = region_index.get(str((value["coordinates"][0]-1, value["coordinates"][1]-1))) == region
        top_right = region_index.get(str((value["coordinates"][0]-1, value["coordinates"][1]+1))) == region
        bottom_left = region_index.get(str((value["coordinates"][0]+1, value["coordinates"][1]-1))) == region
        bottom_right = region_index.get(str((value["coordinates"][0]+1, value["coordinates"][1]+1))) == region
        # print(top, bottom, left, right, top_left, top_right, bottom_left, bottom_right)
        tl_corner = (not top_left and  top and  left) or (not top and not left) # (top_left == False) and ((not top and notleft) or (top == True and left == True    tl_corner = not top_left and ((not top and not left) or (top and left))
        tr_corner = (not top_right and  top and  right) or (not top and not right) # (top_right == False) and ((not top and not right) or (top and right)
        bl_corner = (not bottom_left and  bottom and  left) or (not bottom and not left) # (bottom_left == False) and ((not bottom and not left) or (bottom and left)
        br_corner = (not bottom_right and  bottom and  right) or (not bottom and not right) # (bottom_right == False) and ((not bottom and not right) or (bottom and right)
       
        # print(tl_corner, tr_corner, bl_corner, br_corner)
        if tl_corner:
            corners += 1
        if tr_corner:
            corners += 1
        if bl_corner:
            corners += 1
        if br_corner:
            corners += 1
    # perimeter  = sum([1 for _ in region.keys() if region[key]["is_edge"] == True])
    # area = len(region.keys())
    score = area * perimeter
    scores.append(score)
   
    score2 = area * corners
    # print(area, corners, score2)
    scores2.append(score2)
    # break
    # score = area * perimeter
print(scores)
print("Part 1", sum(scores))
print(scores2)
print("Part 2", sum(scores2))
# Out:
# [736, 1020, 3996, 4, 1330, 8024, 32, 4, 10720, 972, 40, 4, 4, 24, 7770, 1054, 768, 10496, 8610, 12, 1216, 4, 4, 140, 6660, 12, 2912, 1140, 24, 1932, 4, 4, 4, 4, 4, 4, 13464, 7784, 360, 9916, 112, 4, 12838, 128, 4, 6612, 4, 4, 3500, 2688, 4, 12, 4, 11400, 4864, 4, 4, 11616, 84, 4, 3996, 4, 660, 12, 4, 12, 12, 4, 570, 4928, 476, 484, 12, 3172, 4, 12, 242, 4, 5432, 12, 1188, 8066, 4, 12, 4, 4, 23968, 2500, 12, 3360, 40, 4, 1260, 11124, 12, 4, 6402, 4, 4, 588, 352, 160, 4, 162, 4, 60, 12, 12, 6912, 40, 5390, 60, 12, 1840, 84, 3172, 900, 4, 24, 128, 4, 4, 3654, 21670, 4, 24, 504, 40, 390, 12838, 4, 50, 4, 9144, 11070, 4698, 24, 98, 24, 4, 4, 4, 4, 24, 11520, 40, 24, 10400, 1302, 12060, 12, 12, 4, 12, 144, 84, 12, 4, 4, 2332, 4, 12, 4, 84, 4, 60, 13140, 4, 24, 40, 2448, 21710, 4, 2970, 24, 4, 4, 4, 4, 5904, 24, 6786, 40, 4, 32, 4, 12, 7392, 162, 12, 440, 992, 12, 4592, 750, 4, 3300, 4, 2898, 240, 768, 1120, 35040, 360, 112, 4, 1008, 4814, 572, 4, 60, 2976, 24, 84, 12, 162, 12, 4, 12, 624, 
# ...
